# %%
#최고 기온 데이터 히스토그램으로 표현
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
        
plt.hist(result, bins=100, color='r')
plt.show()

# %%
#8월의 최고 기온 데이터 히스토그램으로 표현
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
Aug = []

for row in data:
    if row[-1] != "":
        if row[0].split('-')[1] == "08":
            Aug.append(float(row[-1]))
        
plt.hist(Aug, bins=100, color='r')
plt.show()

# %%
#1월과 8월의 최고 기온 데이터 히스토그램으로 표현
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
Jan = []
Aug = []

for row in data:
    if row[-1] != "":
        if row[0].split('-')[1] == "01":
            Jan.append(float(row[-1]))
        if row[0].split('-')[1] == "08":
            Aug.append(float(row[-1]))

plt.hist(Jan, bins=100, color="b", label = "Jan")
plt.hist(Aug, bins=100, color='r', label= "Aug")
plt.legend()
plt.show()

# %%
#boxplot 연습
import matplotlib.pyplot as plt
import random
import numpy as np
#plt.figure(dpi = 300)

result = []

for i in range(10) :
    result.append(random.randint(1,1000))
print(sorted(result))

result = np.array(result)

print("1/4: " + str(np.percentile(result,25)))
print("2/4: " + str(np.percentile(result,50)))
print("3/4: " + str(np.percentile(result,75)))
plt.boxplot(result)
plt.show()
# Out:
# [5, 48, 260, 280, 351, 382, 661, 738, 843, 854]
# 1/4: 265.0
# 2/4: 366.5
# 3/4: 718.75

# %%
#문제 1
#최고 기온 데이터 상자 그림으로 표현
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != "":
        result.append(float(row[-1]))

plt.boxplot(result)
plt.show()

# %%
#문제 2
#1월과 8월의 최고 기온 데이터 상자 그림으로 표현
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
Jan = []
Aug = []

for row in data:
    if row[-1] != "":
        if row[0].split('-')[1] == "01":
            Jan.append(float(row[-1]))
        if row[0].split('-')[1] == "08":
            Aug.append(float(row[-1]))

plt.boxplot([Jan, Aug])
plt.show()

# %%
#문제 3
#1~12월까지 최고 기온 데이터 상자 그림으로 표현하기
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
Jan = []
Feb = []
Mar = []
Apr = []
May = []
Jun = []
Jul = []
Aug = []
Sep = []
Oct = []
Nov = []
Dec = []

#더 간단한 방법 - 월별 데이터를 저장할 리스트 month 생성(12개)
# month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data:
    if row[-1] != "":
        if row[0].split('-')[1] == "01":
            Jan.append(float(row[-1]))
        if row[0].split('-')[1] == "02":
            Feb.append(float(row[-1]))
        if row[0].split('-')[1] == "03":
            Mar.append(float(row[-1]))
        if row[0].split('-')[1] == "04":
            Apr.append(float(row[-1]))
        if row[0].split('-')[1] == "05":
            May.append(float(row[-1]))
        if row[0].split('-')[1] == "06":
            Jun.append(float(row[-1]))
        if row[0].split('-')[1] == "07":
            Jul.append(float(row[-1]))
        if row[0].split('-')[1] == "08":
            Aug.append(float(row[-1]))
        if row[0].split('-')[1] == "08":
            Sep.append(float(row[-1]))
        if row[0].split('-')[1] == "10":
            Oct.append(float(row[-1]))
        if row[0].split('-')[1] == "11":
            Nov.append(float(row[-1]))
        if row[0].split('-')[1] == "12":
            Dec.append(float(row[-1]))
        
        #더 간단한 방법
        #month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot([Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec])
#plt.boxplot(month)
plt.show()

# %% [markdown]
# 우리 동네 인구조사: age.csv

# %%
#age.csv 읽고 신도림동 데이터 행 출력
import csv

f = open('age.csv')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '37,268', '37,268', '326', '334', '406', '413', '389', '408', '417', '434', '411', '387', '420', '383', '354', '357', '340', '338', '349', '339', '407', '380', '390', '453', '424', '516', '451', '466', '448', '484', '471', '476', '558', '541', '579', '619', '638', '740', '756', '792', '745', '789', '671', '687', '700', '636', '726', '691', '657', '619', '649', '585', '579', '470', '522', '534', '563', '445', '511', '569', '572', '513', '532', '456', '426', '497', '379', '384', '399', '279', '289', '276', '268', '271', '223', '170', '150', '154', '177', '140', '126', '114', '121', '97', '86', '80', '59', '48', '44', '43', '28', '29', '22', '15', '13', '12', '5', '8', '5', '4', '2', '3', '7']

# %%
#우리 동네 연령별 인구수 출력하기
import csv

f = open('age.csv')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            print(i)
# Out:
# 326
# 334
# 406
# 413
# 389
# 408
# 417
# 434
# 411
# 387
# 420
# 383
# 354
# 357
# 340
# 338
# 349
# 339
# 407
# 380
# 390
# 453
# 424
# 516
# 451
# 466
# 448
# 484
# 471
# 476
# 558
# 541
# 579
# 619
# 638
# 740
# 756
# 792
# 745
# 789
# 671
# 687
# 700
# 636
# 726
# 691
# 657
# 619
# 649
# 585
# 579
# 470
# 522
# 534
# 563
# 445
# 511
# 569
# 572
# 513
# 532
# 456
# 426
# 497
# 379
# 384
# 399
# 279
# 289
# 276
# 268
# 271
# 223
# 170
# 150
# 154
# 177
# 140
# 126
# 114
# 121
# 97
# 86
# 80
# 59
# 48
# 44
# 43
# 28
# 29
# 22
# 15
# 13
# 12
# 5
# 8
# 5
# 4
# 2
# 3
# 7

# %%
#문제4
#우리 동네 연련별 인구수 result 리스트에 저장하기
import csv

f = open('age.csv')
data = csv.reader(f)
result = []
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i)) #문자 데이터 정수로 변환
            
print(result)
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
#문제 5
#우리 동네 연령별 인구수 데이터 시각화
import csv
import matplotlib.pyplot as plt

f = open('age.csv')
data = csv.reader(f)
result = []
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))

plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
#문제 6
#지역명을 입력 받아서 연령별 인구수 데이터를 시각화
import csv
import matplotlib.pyplot as plt

f = open('age.csv')
data = csv.reader(f)
result = []

name = input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ")

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i)) 

plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.title(name +  " 지역의 인구 구조")
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 목동

# %%
#막대 그래프 그리기 - bar()함수
import matplotlib.pyplot as plt

plt.bar([0, 1, 2, 4, 6, 10], [1, 2, 3, 5, 6, 7])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(range(6), [1, 2, 3, 5, 6, 7])
plt.show()

# %%
#문제 7
#신도림의 인구 구조 막대 그래프로 표현
import csv
import matplotlib.pyplot as plt

f = open('age.csv')
data = csv.reader(f)
result = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
            
plt.bar(range(101), result)
plt.show()

# %%
#수평 막대 그래프 사용 - barh() 함수
import csv
import matplotlib.pyplot as plt

f = open('age.csv')
data = csv.reader(f)
result = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
            
plt.barh(range(101), result)
plt.show()

# %% [markdown]
# 항아리 모양 그래프 그리기: gender.csv

# %%
#성별 데이터 저장하기(Tpye 1)
#male 데이터: 3~103번 데이터 순차적
#female 데이터: -1~-101번 데이터 순서대로 정한 후 뒤집기
import csv

f = open('gender.csv')
data = csv.reader(f)
m1 = []
f1 = []

for row in data:
    if '신도림' in row[0]:
        for i in range(0, 101):
            m1.append(int(row[i+3]))
            f1.append(int(row[-(i+1)]))
f1.reverse()
    
plt.barh(range(101), m1)
plt.barh(range(101), f1)
plt.show()

# %%
#성별 데이터 저장하고 시각화(Tpye 2)
#male 데이터: 3~103번 데이터 슬라이싱
#female 데이터: 106번~끝까지 데이터 슬라이싱
import csv

f = open('gender.csv')
data = csv.reader(f)
m2 = []
f2 = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:
            m2.append(int(i))
        for i in row[106:]:
            f2.append(int(i))

plt.barh(range(101), m2)
plt.barh(range(101), f2)
plt.show()

# %%
#성별 데이터 수평 막대 그래프로 시각화하기 - 남성 데이터는 음수로
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)
m = []
f = []

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))

# for row in data:
#     if '신도림' in row[0]:
#         for i in range(0, 101):
#             m.append(-int(row[i+3]))
#             f.append(int(row[-(i+1)]))


plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False #마이너스 부호 꺠짐 해결
plt.title('신도림 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label="남성")
plt.barh(range(101), f, label="여성")
plt.legend()
plt.show()

# %%
#문제 8
#찾고 싶은 지역 이름을 입력해서 항아리 모양 그래프 그리기
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)
m = []
f = []

name = input("찾고 싶은 지역의 이름을 알려주세요 : ")


for row in data:
    if name in row[0]:
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))

plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False #마이너스 부호 꺠짐 해결
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label="남성")
plt.barh(range(101), f, label="여성")
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 신도림

# %%
#혈액형 비율 표현하기: pie()함수
import matplotlib.pyplot as plt

plt.pie([10, 20])
plt.show()

# %%
#동그란 원으로 표현
import matplotlib.pyplot as plt

size = ([2441, 2312, 1031, 1233])
plt.axis('equal')
plt.pie(size)
plt.show()

# %%
#레이블 추가하기
import matplotlib.pyplot as plt

plt.rc('font', family = "Malgun Gothic")
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels=label)
plt.show()

# %%
#비율 및 범례 표시하기
import matplotlib.pyplot as plt

plt.rc('font', family = "Malgun Gothic")
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%')
plt.legend()
plt.show()

# %%
#색 및 돌출 효과 표시하기
import matplotlib.pyplot as plt

plt.rc('font', family = "Malgun Gothic")
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))
plt.legend()
plt.show()

# %%
#제주도의 성별 인구 비율 표현하기
import csv

f = open('gender.csv')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')  
for row in data :
    if name in row[0] :
        m = 0
        f = 0
        for i in range(101) :
            m =  m + int(row[i+3])    # 3 ~ 103번까지 데이터 더하기
            f = f + int(row[i+106])  # 106 ~ 206번까지 데이터 더하기
        break
size.append(m)                    # 남성 합계 데이터 리스트에 추가
size.append(f)                    # 여성 합계 데이터 리스트에 추가
print(size)
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도
# [335813, 331524]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels=["남", '여'], autopct='%.1f%%', colors=color, startangle=90)
plt.title(name+" 지역의 남녀 성별 비율")
plt.show()
